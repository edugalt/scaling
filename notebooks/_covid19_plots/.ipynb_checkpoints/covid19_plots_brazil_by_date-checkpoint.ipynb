# %%
'''libraries list with help showing the version of the libraries being used in this nodebook'''
libraries = []
import random
'''Datasets, arrays and json files'''

import pandas as pd
import numpy as np
import pickle

libraries.append('pandas')
libraries.append('numpy')
libraries.append('pickle')

'''Following progress'''
from tqdm.notebook import tqdm
libraries.append('tqdm')

'''Utilities'''
import collections
from pathlib import Path
from datetime import datetime
import os
import powerlaw 
libraries.append('collections')
libraries.append('pathlib')
libraries.append('datetime')
libraries.append('os')
libraries.append('powerlaw')

'''Plots and figures'''
# %matplotlib notebook

import matplotlib.pyplot as plt
import plotly.express as px
libraries.append('matplotlib')
libraries.append('plotly')

plt.rcParams["figure.facecolor"] = "w"

'''Pthon and library version'''
import types
import pkg_resources
import sys
from platform import python_version

# %%
# !ls '../_generated_files/Brazil_by_dates'
# Out:
# Brazil_105.csv Brazil_205.csv Brazil_295.csv Brazil_370.csv Brazil_450txt
# Brazil_105txt  Brazil_205txt  Brazil_295txt  Brazil_370txt  Brazil_45txt
# Brazil_115.csv Brazil_215.csv Brazil_30.csv  Brazil_38.csv  Brazil_460.csv
# Brazil_115txt  Brazil_215txt  Brazil_300.csv Brazil_380.csv Brazil_460txt
# Brazil_125.csv Brazil_225.csv Brazil_300txt  Brazil_380txt  Brazil_470.csv
# Brazil_125txt  Brazil_225txt  Brazil_30txt   Brazil_38txt   Brazil_470txt
# Brazil_135.csv Brazil_235.csv Brazil_310.csv Brazil_390.csv Brazil_480.csv
# Brazil_135txt  Brazil_235txt  Brazil_310txt  Brazil_390txt  Brazil_480txt
# Brazil_145.csv Brazil_245.csv Brazil_320.csv Brazil_400.csv Brazil_490.csv
# Brazil_145txt  Brazil_245txt  Brazil_320txt  Brazil_400txt  Brazil_490txt
# Brazil_155.csv Brazil_25.csv  Brazil_330.csv Brazil_410.csv Brazil_55.csv
# Brazil_155txt  Brazil_255.csv Brazil_330txt  Brazil_410txt  Brazil_55txt
# Brazil_165.csv Brazil_255txt  Brazil_340.csv Brazil_420.csv Brazil_65.csv
# ...

# %%
name_options = ['Brazil_25d_1060c',
                'Brazil_30d_2891c',
                'Brazil_35d_5712c',
                'Brazil_38d_9064c',
                'Brazil_45d_19721c',
                'Brazil_55d_40606c',
                'Brazil_60d_57962c',
                'Brazil_65d_86732c',
                'Brazil_70d_115411c',
                'Brazil_75d_162681c',
                'Brazil_80d_219190c',
                'Brazil_85d_289538c',
                'Brazil_95d_499331c',
                'Brazil_105d_737661c',
                'Brazil_115d_1032352c',
                'Brazil_125d_1361797c',
                'Brazil_135d_1749975c',
                'Brazil_145d_2083402c',
                'Brazil_155d_2535667c',
                'Brazil_165d_2987659c',
                'Brazil_175d_3371142c',
                'Brazil_185d_3750432c',
                'Brazil_195d_4076635c',
                'Brazil_205d_4370604c',
                'Brazil_215d_4630632c',
                'Brazil_225d_4888866c',
                'Brazil_235d_5100292c',
                'Brazil_245d_5317993c',
                'Brazil_255d_5504704c',
                'Brazil_265d_5740203c',
                'Brazil_275d_6155511c',
                'Brazil_285d_6547318c',
                'Brazil_295d_6983680c',
                'Brazil_300d_7205953c',
                'Brazil_310d_7613958c',
                'Brazil_320d_8039764c',
                'Brazil_330d_8570702c',
                'Brazil_340d_9099387c',
                'Brazil_350d_9519703c',
                'Brazil_360d_10009350c',
                'Brazil_370d_10511827c',
                'Brazil_380d_11215600c',
                'Brazil_390d_11926059c',
                'Brazil_400d_12682678c',
                'Brazil_410d_13307252c',
                'Brazil_420d_13841649c',
                'Brazil_430d_14588604c',
                'Brazil_440d_15140598c',
                'Brazil_450d_15815865c',
                'Brazil_460d_16415399c',
                'Brazil_470d_17039768c',
                'Brazil_480d_17793240c',
                'Brazil_490d_18344475c']

# %%
#Pop
pop_beta = {}
pop_error = {}
#LS
ls_beta = {}
ls_error = {}
for n in name_options:
    try:
        with open('results/results_'+n+'.pickle', 'rb') as handle: 
            results = pickle.load(handle)
    except:
        break
    (beta, error) =results['Pop']['Beta +- error']
    pop_beta[n] = beta
    pop_error[n] = error
    k =results['LS']
    ls_beta[n] = k[0]
    ls_error[n] = k[1]

# %%
print(len(ls_beta))
len(n)
# Out:
# 53
# 52

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


i = 0
n = [25, 30, 35, 38, 45, 55, 60, 65, 70, 75, 80, 85, 95, 105,
     115, 125, 135, 145, 155, 165, 175, 185, 195, 205, 
     215, 225, 235, 245, 255, 265, 275, 285, 295, 300, 
     310, 320, 330, 340, 350, 360, 370, 380, 390, 400,
    410, 420, 430, 440, 450, 460, 470, 480, 490]

days_cases = {25:1060, 30:2891, 35:5712, 38:9064, 45:19721, 55:40606, 
              60:57962, 65:86732, 70:115411, 75:162681, 80:219190,
              85:289538, 95:499331, 105:737661, 115:1032352, 125:1361797,
              135:1749975, 145:2083402, 155:2535667, 165:2987659, 175:3371142,
              185:3750432, 195:4076635, 205:4370604, 215:4630632, 225:4888866,
              235:5100292, 245:5317993, 255:5504704, 265:5740203, 275:6155511,
              285:6547318, 295:6983680, 300:7205953, 310:7613958, 320:8039764,
              330:8570702, 340:9099387, 350:9519703, 360:10009350, 370:10511827, 
              380:11215600, 390:11926059, 400:12682678, 410:13307252, 
              420:13841649, 430:14588604, 440:15140598, 450:15815865, 
              460:16415399, 470:17039768, 480:17793240, 490:18344475} 
handles_x = []
fig, ax1 = plt.subplots()

#fig, ax1 = plt.figure(figsize=(5, 4), dpi=100)
#ax1 = fig.add_subplot(111)


ax1.axhline(y=1, color='royalblue', alpha = 0.3, linestyle='--')
ax1.axvline(x=293, color='black', alpha = 0.3, linestyle='--', label='No zero cases')
handles_x, labels = plt.gca().get_legend_handles_labels()
red_patch = mpatches.Patch(color='tomato', label='Least Square')
green_patch = mpatches.Patch(color='limegreen', label="Person's Model")

for name, value in pop_beta.items():
    x = n[i]
    y = pop_beta[name]
    
    yerr =pop_error[name]
    ax1.scatter(x, y, label=name, color="limegreen", alpha = 0.5)
    ax1.errorbar(x, y, yerr=yerr, color="limegreen", alpha = 0.5, label=name)
    i += 1
    #upperlimits = [True, False] * 5
    #lowerlimits = [False, True] * 5
    #plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
    #             label='subsets of uplims and lolims')

    #plt.legend(loc='best')


handles_x.append(red_patch)
handles_x.append(green_patch)


i = 0
for name, value in ls_beta.items():
    x = n[i] #should be days and annotate number of cases
    y = ls_beta[name]
    yerr =ls_error[name]
    ax1.scatter(x, y, label=name, color="tomato", alpha = 0.5)
    ax1.errorbar(x, y, yerr=yerr, color="tomato", alpha = 0.5)
    i += 1

#ax2 = ax1.twinx()

#days = list(days_cases.keys())
#cases = list(days_cases.values())

#ax2.plot(days, cases, color='goldenrod',alpha = 0.3, linestyle='--')
#ax2.tick_params(axis='y', labelcolor='goldenrod',  alpha = 0.3, linestyle='--')


#ax2.set_ylabel('Cases')  # we already handled the x-label with ax1
ax1.legend(handles=handles_x, loc='upper right')
ax1.set_ylabel(r"$\beta$") 
plt.xlabel("Days")
plt.savefig('Betas_Brazil', dpi = 1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pop_beta[name]
# Out:
# 1.2011427205534924

# %%
list(days_cases.keys())
# Out:
# [25,
#  30,
#  35,
#  38,
#  45,
#  55,
#  60,
#  65,
#  70,
#  75,
#  80,
#  85,
#  95,
#  105,
#  115,
#  125,
#  135,
#  145,
#  155,
#  165,
#  175,
#  185,
#  195,
#  205,
#  215,
#  225,
#  235,
#  245,
#  255,
#  265,
#  275,
#  285,
#  295,
#  300,
#  310,
#  320,
#  330,
#  340,
#  350,
#  360,
#  370,
#  380,
#  390,
#  400,
#  410,
#  420,
#  430,
#  440,
#  450,
#  460,
#  470,
#  480,
#  490]
